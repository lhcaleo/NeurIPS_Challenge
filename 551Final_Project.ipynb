# %% [markdown]
# <a href="https://colab.research.google.com/github/lhcaleo/NeurIPS_Challenge/blob/master/551Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Mount Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # **Load File Location**

# %%
cd '/content/drive/My Drive/Colab Notebooks/dragonnet-master/src'
# Out:
# /content/drive/My Drive/Colab Notebooks/dragonnet-master/src

# %% [markdown]
# # **idhp_dragonnet.py**

# %%
from experiment.models import *
import os
import glob
import argparse
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import keras.backend as K
from keras.optimizers import rmsprop, SGD, Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard, ReduceLROnPlateau, TerminateOnNaN
from experiment.idhp_data import *

print(tf.__version__)

def _split_output(yt_hat, t, y, y_scaler, x, index):
    q_t0 = y_scaler.inverse_transform(yt_hat[:, 0].copy())
    q_t1 = y_scaler.inverse_transform(yt_hat[:, 1].copy())
    g = yt_hat[:, 2].copy()

    if yt_hat.shape[1] == 4:
        eps = yt_hat[:, 3][0]
    else:
        eps = np.zeros_like(yt_hat[:, 2])

    y = y_scaler.inverse_transform(y.copy())
    var = "average propensity for treated: {} and untreated: {}".format(g[t.squeeze() == 1.].mean(),
                                                                        g[t.squeeze() == 0.].mean())
    print(var)

    return {'q_t0': q_t0, 'q_t1': q_t1, 'g': g, 't': t, 'y': y, 'x': x, 'index': index, 'eps': eps}


def train_and_predict_dragons(t, y_unscaled, x, targeted_regularization=True, output_dir='',
                              knob_loss=dragonnet_loss_binarycross, ratio=1, dragon='', val_split=0.2, batch_size=64):
    print(val_split)
    verbose = 0
    y_scaler = StandardScaler().fit(y_unscaled)
    y = y_scaler.transform(y_unscaled)
    train_outputs = []
    test_outputs = []

    if dragon == 'tarnet':
        dragonnet = make_tarnet(x.shape[1], 0.01)

    elif dragon == 'dragonnet':
        print("I am here making dragonnet")
        dragonnet = make_dragonnet(x.shape[1], 0.01)

    metrics = [regression_loss, binary_classification_loss, treatment_accuracy, track_epsilon]

    if targeted_regularization:
        loss = make_tarreg_loss(ratio=ratio, dragonnet_loss=knob_loss)
    else:
        loss = knob_loss

    # for reporducing the IHDP experimemt

    i = 0
    tf.random.set_random_seed(i)
    np.random.seed(i)

    test_size = 0.0001
    train_index, test_index = train_test_split(np.arange(x.shape[0]), test_size=test_size)
    if test_size == 0.0001:
        test_index = train_index

    x_train, x_test = x[train_index], x[test_index]
    y_train, y_test = y[train_index], y[test_index]
    t_train, t_test = t[train_index], t[test_index]

    yt_train = np.concatenate([y_train, t_train], 1)

    import time;
    start_time = time.time()

    dragonnet.compile(
        optimizer=Adam(lr=1e-3),
        loss=loss, metrics=metrics)

    adam_callbacks = [
        TerminateOnNaN(),
        EarlyStopping(monitor='val_loss', patience=2, min_delta=0.),
        ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, verbose=verbose, mode='auto',
                          min_delta=1e-8, cooldown=0, min_lr=0)

    ]

    dragonnet.fit(x_train, yt_train, callbacks=adam_callbacks,
                  validation_split=val_split,
                  epochs=100,
                  batch_size=batch_size, verbose=verbose)

    sgd_callbacks = [
        TerminateOnNaN(),
        EarlyStopping(monitor='val_loss', patience=40, min_delta=0.),
        ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, verbose=verbose, mode='auto',
                          min_delta=0., cooldown=0, min_lr=0)
    ]

    sgd_lr = 1e-5
    momentum = 0.9
    dragonnet.compile(optimizer=SGD(lr=sgd_lr, momentum=momentum, nesterov=True), loss=loss,
                      metrics=metrics)
    dragonnet.fit(x_train, yt_train, callbacks=sgd_callbacks,
                  validation_split=val_split,
                  epochs=300,
                  batch_size=batch_size, verbose=verbose)

    elapsed_time = time.time() - start_time
    print("***************************** elapsed_time is: ", elapsed_time)

    yt_hat_test = dragonnet.predict(x_test)
    yt_hat_train = dragonnet.predict(x_train)

    test_outputs += [_split_output(yt_hat_test, t_test, y_test, y_scaler, x_test, test_index)]
    train_outputs += [_split_output(yt_hat_train, t_train, y_train, y_scaler, x_train, train_index)]
    K.clear_session()

    return test_outputs, train_outputs


def train_and_predict_ned(t, y_unscaled, x, targeted_regularization=True, output_dir='',
                          knob_loss=dragonnet_loss_binarycross, ratio=1., dragon='', val_split=0.2, batch_size=64):
    verbose = 0
    y_scaler = StandardScaler().fit(y_unscaled)
    y = y_scaler.transform(y_unscaled)

    train_outputs = []
    test_outputs = []

    nednet = make_ned(x.shape[1], 0.01)

    metrics_ned = [ned_loss]
    metrics_cut = [regression_loss]

    # for reproducing the ihdp result
    i = 0

    tf.random.set_random_seed(i)
    np.random.seed(i)

    # change the test_size to get in sample and out sample estimates

    test_size = 0.0001
    train_index, test_index = train_test_split(np.arange(x.shape[0]), test_size=test_size)
    if test_size == 0.0001:
        test_index = train_index

    x_train, x_test = x[train_index], x[test_index]
    y_train, y_test = y[train_index], y[test_index]
    t_train, t_test = t[train_index], t[test_index]
    yt_train = np.concatenate([y_train, t_train], 1)


    nednet.compile(
        optimizer=Adam(lr=1e-3),
        loss=ned_loss, metrics=metrics_ned)

    adam_callbacks = [
        TerminateOnNaN(),
        EarlyStopping(monitor='val_loss', patience=2, min_delta=0.),
        ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, verbose=verbose, mode='auto',
                          min_delta=1e-8, cooldown=0, min_lr=0)
    ]

    nednet.fit(x_train, yt_train, callbacks=adam_callbacks,
               validation_split=val_split,
               epochs=100,
               batch_size=batch_size, verbose=verbose)

    sgd_callbacks = [
        TerminateOnNaN(),
        EarlyStopping(monitor='val_loss', patience=40, min_delta=0.),
        ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, verbose=verbose, mode='auto',
                          min_delta=0., cooldown=0, min_lr=0)]

    sgd_lr = 1e-5
    momentum = 0.9
    nednet.compile(optimizer=SGD(lr=sgd_lr, momentum=momentum, nesterov=True), loss=ned_loss,
                   metrics=metrics_ned)
    print(nednet.summary())
    nednet.fit(x_train, yt_train, callbacks=sgd_callbacks,
               validation_split=val_split,
               epochs=300,
               batch_size=batch_size, verbose=verbose)

    t_hat_test = nednet.predict(x_test)[:, 1]
    t_hat_train = nednet.predict(x_train)[:, 1]

    # cutting the activation layer
    cut_net = post_cut(nednet, x.shape[1], 0.01)

    cut_net.compile(
        optimizer=Adam(lr=1e-3),
        loss=dead_loss, metrics=metrics_cut)

    adam_callbacks = [
        TerminateOnNaN(),
        EarlyStopping(monitor='val_loss', patience=2, min_delta=0.),
        ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, verbose=verbose, mode='auto',
                          min_delta=1e-8, cooldown=0, min_lr=0)
    ]

    cut_net.fit(x_train, yt_train, callbacks=adam_callbacks,
                validation_split=val_split,
                epochs=100,
                batch_size=batch_size, verbose=verbose)

    sgd_callbacks = [
        TerminateOnNaN(),
        EarlyStopping(monitor='val_loss', patience=40, min_delta=0.),
        ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, verbose=verbose, mode='auto',
                          min_delta=0., cooldown=0, min_lr=0)]

    sgd_lr = 1e-5
    momentum = 0.9
    cut_net.compile(optimizer=SGD(lr=sgd_lr, momentum=momentum, nesterov=True), loss=dead_loss,
                    metrics=metrics_cut)

    cut_net.fit(x_train, yt_train, callbacks=sgd_callbacks,
                validation_split=val_split,
                epochs=300,
                batch_size=batch_size, verbose=verbose)

    y_hat_test = cut_net.predict(x_test)
    y_hat_train = cut_net.predict(x_train)

    yt_hat_test = np.concatenate([y_hat_test, t_hat_test.reshape(-1, 1)], 1)
    yt_hat_train = np.concatenate([y_hat_train, t_hat_train.reshape(-1, 1)], 1)

    test_outputs += [_split_output(yt_hat_test, t_test, y_test, y_scaler, x_test, test_index)]
    train_outputs += [_split_output(yt_hat_train, t_train, y_train, y_scaler, x_train, train_index)]
    K.clear_session()

    return test_outputs, train_outputs


def run_ihdp(data_base_dir='/Users/claudiashi/data/ihdp_csv', output_dir='~/result/ihdp/',
             knob_loss=dragonnet_loss_binarycross,
             ratio=1., dragon=''):
    print("the dragon is {}".format(dragon))

    simulation_files = sorted(glob.glob("{}/*.csv".format(data_base_dir)))

    for idx, simulation_file in enumerate(simulation_files):

        simulation_output_dir = os.path.join(output_dir, str(idx))

        os.makedirs(simulation_output_dir, exist_ok=True)

        x = load_and_format_covariates_ihdp(simulation_file)
        t, y, y_cf, mu_0, mu_1 = load_all_other_crap(simulation_file)
        np.savez_compressed(os.path.join(simulation_output_dir, "simulation_outputs.npz"),
                            t=t, y=y, y_cf=y_cf, mu_0=mu_0, mu_1=mu_1)

        for is_targeted_regularization in [True, False]:
            print("Is targeted regularization: {}".format(is_targeted_regularization))
            if dragon == 'nednet':
                test_outputs, train_output = train_and_predict_ned(t, y, x,
                                                                   targeted_regularization=is_targeted_regularization,
                                                                   output_dir=simulation_output_dir,
                                                                   knob_loss=knob_loss, ratio=ratio, dragon=dragon,
                                                                   val_split=0.3, batch_size=64)
            else:

                test_outputs, train_output = train_and_predict_dragons(t, y, x,
                                                                       targeted_regularization=is_targeted_regularization,
                                                                       output_dir=simulation_output_dir,
                                                                       knob_loss=knob_loss, ratio=ratio, dragon=dragon,
                                                                       val_split=0.2, batch_size=64)

            if is_targeted_regularization:
                train_output_dir = os.path.join(simulation_output_dir, "targeted_regularization")
            else:
                train_output_dir = os.path.join(simulation_output_dir, "baseline")
            os.makedirs(train_output_dir, exist_ok=True)

            # save the outputs of for each split (1 per npz file)
            for num, output in enumerate(test_outputs):
                np.savez_compressed(os.path.join(train_output_dir, "{}_replication_test.npz".format(num)),
                                    **output)

            for num, output in enumerate(train_output):
                np.savez_compressed(os.path.join(train_output_dir, "{}_replication_train.npz".format(num)),
                                    **output)


def turn_knob(data_base_dir='/Users/claudiashi/data/test/', knob='dragonnet',
              output_base_dir=''):
    output_dir = os.path.join(output_base_dir, knob)

    if knob == 'dragonnet':
        run_ihdp(data_base_dir=data_base_dir, output_dir=output_dir, dragon='dragonnet')

    if knob == 'tarnet':
        run_ihdp(data_base_dir=data_base_dir, output_dir=output_dir, dragon='tarnet')

    if knob == 'nednet':
        run_ihdp(data_base_dir=data_base_dir, output_dir=output_dir, dragon='nednet')
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Using TensorFlow backend.
# 1.15.0

# %% [markdown]
# # **Run Dragonnet**

# %%
def main():
    #turn_knob(args.data_base_dir, args.knob, args.folder, args.output_base_dir, args.dataset)
    turn_knob(data_base_dir='/content/drive/My Drive/Colab Notebooks/dragonnet-master/dat/ihdp/csv', 
    knob='dragonnet', 
    output_base_dir='/content/drive/My Drive/Colab Notebooks/dragonnet-master/src/Result') 


if __name__ == '__main__':
    main()

print("run_dragonnet_done")
# Out:
# the dragon is dragonnet
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4409: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# ***************************** elapsed_time is:  11.101672887802124
# average propensity for treated: 0.26416459679603577 and untreated: 0.17697075009346008
# average propensity for treated: 0.26416459679603577 and untreated: 0.17697075009346008
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:107: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:111: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  5.841557502746582
# average propensity for treated: 0.27276259660720825 and untreated: 0.17516310513019562
# average propensity for treated: 0.27276259660720825 and untreated: 0.17516310513019562
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  12.943016529083252
# average propensity for treated: 0.2528091371059418 and untreated: 0.17777119576931
# average propensity for treated: 0.2528091371059418 and untreated: 0.17777119576931
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  11.751819133758545
# average propensity for treated: 0.2608446180820465 and untreated: 0.17622756958007812
# average propensity for treated: 0.2608446180820465 and untreated: 0.17622756958007812
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  13.449672937393188
# average propensity for treated: 0.2548747956752777 and untreated: 0.176809623837471
# average propensity for treated: 0.2548747956752777 and untreated: 0.176809623837471
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  11.417734146118164
# average propensity for treated: 0.2647412121295929 and untreated: 0.17498470842838287
# average propensity for treated: 0.2647412121295929 and untreated: 0.17498470842838287
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  10.574452877044678
# average propensity for treated: 0.2629607319831848 and untreated: 0.17458587884902954
# average propensity for treated: 0.2629607319831848 and untreated: 0.17458587884902954
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  7.677576303482056
# average propensity for treated: 0.274461954832077 and untreated: 0.17338800430297852
# average propensity for treated: 0.274461954832077 and untreated: 0.17338800430297852
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  10.046391010284424
# average propensity for treated: 0.25200051069259644 and untreated: 0.17582868039608002
# average propensity for treated: 0.25200051069259644 and untreated: 0.17582868039608002
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  9.948339700698853
# average propensity for treated: 0.2695818841457367 and untreated: 0.1736694574356079
# average propensity for treated: 0.2695818841457367 and untreated: 0.1736694574356079
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  6.503725051879883
# average propensity for treated: 0.2514818012714386 and untreated: 0.1816493421792984
# average propensity for treated: 0.2514818012714386 and untreated: 0.1816493421792984
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  11.148636102676392
# average propensity for treated: 0.26808252930641174 and untreated: 0.1773044615983963
# average propensity for treated: 0.26808252930641174 and untreated: 0.1773044615983963
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  12.989655494689941
# average propensity for treated: 0.25377777218818665 and untreated: 0.17568348348140717
# average propensity for treated: 0.25377777218818665 and untreated: 0.17568348348140717
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  11.221623420715332
# average propensity for treated: 0.26238617300987244 and untreated: 0.17715409398078918
# average propensity for treated: 0.26238617300987244 and untreated: 0.17715409398078918
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  12.481531381607056
# average propensity for treated: 0.2687196135520935 and untreated: 0.17707796394824982
# average propensity for treated: 0.2687196135520935 and untreated: 0.17707796394824982
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  5.855145454406738
# average propensity for treated: 0.2718130052089691 and untreated: 0.17523375153541565
# average propensity for treated: 0.2718130052089691 and untreated: 0.17523375153541565
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  9.680781841278076
# average propensity for treated: 0.26431894302368164 and untreated: 0.1764284074306488
# average propensity for treated: 0.26431894302368164 and untreated: 0.1764284074306488
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  8.280428171157837
# average propensity for treated: 0.27307963371276855 and untreated: 0.17416130006313324
# average propensity for treated: 0.27307963371276855 and untreated: 0.17416130006313324
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  10.631809949874878
# average propensity for treated: 0.25682753324508667 and untreated: 0.17742502689361572
# average propensity for treated: 0.25682753324508667 and untreated: 0.17742502689361572
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  11.830035924911499
# average propensity for treated: 0.2647722065448761 and untreated: 0.17645208537578583
# average propensity for treated: 0.2647722065448761 and untreated: 0.17645208537578583
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  12.867651462554932
# average propensity for treated: 0.2406516820192337 and untreated: 0.18073770403862
# average propensity for treated: 0.2406516820192337 and untreated: 0.18073770403862
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  6.473275184631348
# average propensity for treated: 0.2779497802257538 and untreated: 0.17358647286891937
# average propensity for treated: 0.2779497802257538 and untreated: 0.17358647286891937
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  7.481596946716309
# average propensity for treated: 0.24205268919467926 and untreated: 0.1846437156200409
# average propensity for treated: 0.24205268919467926 and untreated: 0.1846437156200409
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  6.930501937866211
# average propensity for treated: 0.2538638710975647 and untreated: 0.1804104894399643
# average propensity for treated: 0.2538638710975647 and untreated: 0.1804104894399643
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  8.157536506652832
# average propensity for treated: 0.2501804530620575 and untreated: 0.17917197942733765
# average propensity for treated: 0.2501804530620575 and untreated: 0.17917197942733765
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  5.560400724411011
# average propensity for treated: 0.26175951957702637 and untreated: 0.17723089456558228
# average propensity for treated: 0.26175951957702637 and untreated: 0.17723089456558228
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  10.357576131820679
# average propensity for treated: 0.2671951651573181 and untreated: 0.175235778093338
# average propensity for treated: 0.2671951651573181 and untreated: 0.175235778093338
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  6.259289264678955
# average propensity for treated: 0.2738328278064728 and untreated: 0.17375478148460388
# average propensity for treated: 0.2738328278064728 and untreated: 0.17375478148460388
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  7.407911539077759
# average propensity for treated: 0.2647723853588104 and untreated: 0.17632710933685303
# average propensity for treated: 0.2647723853588104 and untreated: 0.17632710933685303
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  5.972004652023315
# average propensity for treated: 0.27438437938690186 and untreated: 0.17393265664577484
# average propensity for treated: 0.27438437938690186 and untreated: 0.17393265664577484
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  9.995728254318237
# average propensity for treated: 0.258827269077301 and untreated: 0.17711861431598663
# average propensity for treated: 0.258827269077301 and untreated: 0.17711861431598663
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  9.532734155654907
# average propensity for treated: 0.264059454202652 and untreated: 0.17685361206531525
# average propensity for treated: 0.264059454202652 and untreated: 0.17685361206531525
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  12.696528673171997
# average propensity for treated: 0.2613149583339691 and untreated: 0.17571428418159485
# average propensity for treated: 0.2613149583339691 and untreated: 0.17571428418159485
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  11.779629468917847
# average propensity for treated: 0.2675657868385315 and untreated: 0.17546319961547852
# average propensity for treated: 0.2675657868385315 and untreated: 0.17546319961547852
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  11.075194120407104
# average propensity for treated: 0.24642527103424072 and untreated: 0.1764102429151535
# average propensity for treated: 0.24642527103424072 and untreated: 0.1764102429151535
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  5.771307706832886
# average propensity for treated: 0.26993685960769653 and untreated: 0.1749286651611328
# average propensity for treated: 0.26993685960769653 and untreated: 0.1749286651611328
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  10.24704885482788
# average propensity for treated: 0.2597065269947052 and untreated: 0.17812833189964294
# average propensity for treated: 0.2597065269947052 and untreated: 0.17812833189964294
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  9.504125595092773
# average propensity for treated: 0.27069488167762756 and untreated: 0.17463912069797516
# average propensity for treated: 0.27069488167762756 and untreated: 0.17463912069797516
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  8.131684064865112
# average propensity for treated: 0.2389596551656723 and untreated: 0.18281331658363342
# average propensity for treated: 0.2389596551656723 and untreated: 0.18281331658363342
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  6.47784686088562
# average propensity for treated: 0.26915356516838074 and untreated: 0.17636054754257202
# average propensity for treated: 0.26915356516838074 and untreated: 0.17636054754257202
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  13.92348575592041
# average propensity for treated: 0.2610777020454407 and untreated: 0.17678986489772797
# average propensity for treated: 0.2610777020454407 and untreated: 0.17678986489772797
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  10.978154420852661
# average propensity for treated: 0.26576974987983704 and untreated: 0.1758304238319397
# average propensity for treated: 0.26576974987983704 and untreated: 0.1758304238319397
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  9.588661670684814
# average propensity for treated: 0.2681034505367279 and untreated: 0.17577093839645386
# average propensity for treated: 0.2681034505367279 and untreated: 0.17577093839645386
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  6.706611156463623
# average propensity for treated: 0.26802825927734375 and untreated: 0.17505787312984467
# average propensity for treated: 0.26802825927734375 and untreated: 0.17505787312984467
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  8.231847763061523
# average propensity for treated: 0.2702638506889343 and untreated: 0.17544206976890564
# average propensity for treated: 0.2702638506889343 and untreated: 0.17544206976890564
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  9.792854070663452
# average propensity for treated: 0.2613944113254547 and untreated: 0.177665576338768
# average propensity for treated: 0.2613944113254547 and untreated: 0.177665576338768
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  8.251473188400269
# average propensity for treated: 0.2704088091850281 and untreated: 0.17536866664886475
# average propensity for treated: 0.2704088091850281 and untreated: 0.17536866664886475
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  9.29554009437561
# average propensity for treated: 0.2758539617061615 and untreated: 0.17396359145641327
# average propensity for treated: 0.2758539617061615 and untreated: 0.17396359145641327
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  10.562166452407837
# average propensity for treated: 0.2668927013874054 and untreated: 0.17522083222866058
# average propensity for treated: 0.2668927013874054 and untreated: 0.17522083222866058
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  10.298534154891968
# average propensity for treated: 0.27413737773895264 and untreated: 0.17379941046237946
# average propensity for treated: 0.27413737773895264 and untreated: 0.17379941046237946
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  9.11860728263855
# average propensity for treated: 0.2606167793273926 and untreated: 0.17904333770275116
# average propensity for treated: 0.2606167793273926 and untreated: 0.17904333770275116
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  9.479167938232422
# average propensity for treated: 0.2753145694732666 and untreated: 0.17493169009685516
# average propensity for treated: 0.2753145694732666 and untreated: 0.17493169009685516
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  10.36102294921875
# average propensity for treated: 0.25405147671699524 and untreated: 0.17912337183952332
# average propensity for treated: 0.25405147671699524 and untreated: 0.17912337183952332
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  5.9750587940216064
# average propensity for treated: 0.26620349287986755 and untreated: 0.17542454600334167
# average propensity for treated: 0.26620349287986755 and untreated: 0.17542454600334167
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  10.998705625534058
# average propensity for treated: 0.26394274830818176 and untreated: 0.17616121470928192
# average propensity for treated: 0.26394274830818176 and untreated: 0.17616121470928192
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  9.373640060424805
# average propensity for treated: 0.27260226011276245 and untreated: 0.17488673329353333
# average propensity for treated: 0.27260226011276245 and untreated: 0.17488673329353333
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  10.868244409561157
# average propensity for treated: 0.263608455657959 and untreated: 0.17570675909519196
# average propensity for treated: 0.263608455657959 and untreated: 0.17570675909519196
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  11.672284126281738
# average propensity for treated: 0.27078977227211 and untreated: 0.17448782920837402
# average propensity for treated: 0.27078977227211 and untreated: 0.17448782920837402
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  13.392683029174805
# average propensity for treated: 0.25812241435050964 and untreated: 0.17846694588661194
# average propensity for treated: 0.25812241435050964 and untreated: 0.17846694588661194
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  11.864956617355347
# average propensity for treated: 0.26787635684013367 and untreated: 0.17573755979537964
# average propensity for treated: 0.26787635684013367 and untreated: 0.17573755979537964
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  12.99262809753418
# average propensity for treated: 0.27273252606391907 and untreated: 0.17458102107048035
# average propensity for treated: 0.27273252606391907 and untreated: 0.17458102107048035
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  6.994479417800903
# average propensity for treated: 0.2780819237232208 and untreated: 0.1732948273420334
# average propensity for treated: 0.2780819237232208 and untreated: 0.1732948273420334
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  10.006939172744751
# average propensity for treated: 0.26233530044555664 and untreated: 0.17682763934135437
# average propensity for treated: 0.26233530044555664 and untreated: 0.17682763934135437
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  8.713996171951294
# average propensity for treated: 0.27859970927238464 and untreated: 0.17288605868816376
# average propensity for treated: 0.27859970927238464 and untreated: 0.17288605868816376
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  12.31613302230835
# average propensity for treated: 0.24823854863643646 and untreated: 0.1778496503829956
# average propensity for treated: 0.24823854863643646 and untreated: 0.1778496503829956
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  9.6722891330719
# average propensity for treated: 0.27341070771217346 and untreated: 0.1749204695224762
# average propensity for treated: 0.27341070771217346 and untreated: 0.1749204695224762
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  10.143401861190796
# average propensity for treated: 0.2674362361431122 and untreated: 0.17604781687259674
# average propensity for treated: 0.2674362361431122 and untreated: 0.17604781687259674
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  10.588491439819336
# average propensity for treated: 0.2661072611808777 and untreated: 0.17757564783096313
# average propensity for treated: 0.2661072611808777 and untreated: 0.17757564783096313
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  7.105306148529053
# average propensity for treated: 0.2577366530895233 and untreated: 0.1774674355983734
# average propensity for treated: 0.2577366530895233 and untreated: 0.1774674355983734
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  6.1043860912323
# average propensity for treated: 0.27135565876960754 and untreated: 0.17486102879047394
# average propensity for treated: 0.27135565876960754 and untreated: 0.17486102879047394
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  13.954841136932373
# average propensity for treated: 0.2702881097793579 and untreated: 0.1760881096124649
# average propensity for treated: 0.2702881097793579 and untreated: 0.1760881096124649
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  10.005838632583618
# average propensity for treated: 0.26679906249046326 and untreated: 0.17797638475894928
# average propensity for treated: 0.26679906249046326 and untreated: 0.17797638475894928
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  6.047892093658447
# average propensity for treated: 0.25055989623069763 and untreated: 0.18204927444458008
# average propensity for treated: 0.25055989623069763 and untreated: 0.18204927444458008
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  5.464871883392334
# average propensity for treated: 0.2584918141365051 and untreated: 0.17916986346244812
# average propensity for treated: 0.2584918141365051 and untreated: 0.17916986346244812
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  7.982072591781616
# average propensity for treated: 0.2627517282962799 and untreated: 0.1748315840959549
# average propensity for treated: 0.2627517282962799 and untreated: 0.1748315840959549
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  9.153831720352173
# average propensity for treated: 0.25888288021087646 and untreated: 0.17573565244674683
# average propensity for treated: 0.25888288021087646 and untreated: 0.17573565244674683
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  13.455018758773804
# average propensity for treated: 0.24567840993404388 and untreated: 0.1803504377603531
# average propensity for treated: 0.24567840993404388 and untreated: 0.1803504377603531
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  12.285671710968018
# average propensity for treated: 0.26898884773254395 and untreated: 0.17578355967998505
# average propensity for treated: 0.26898884773254395 and untreated: 0.17578355967998505
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  13.064713716506958
# average propensity for treated: 0.2734749913215637 and untreated: 0.17427264153957367
# average propensity for treated: 0.2734749913215637 and untreated: 0.17427264153957367
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  11.23790454864502
# average propensity for treated: 0.2750895321369171 and untreated: 0.17407816648483276
# average propensity for treated: 0.2750895321369171 and untreated: 0.17407816648483276
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  8.747570991516113
# average propensity for treated: 0.25843346118927 and untreated: 0.17708253860473633
# average propensity for treated: 0.25843346118927 and untreated: 0.17708253860473633
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  8.003289461135864
# average propensity for treated: 0.26943323016166687 and untreated: 0.1759093552827835
# average propensity for treated: 0.26943323016166687 and untreated: 0.1759093552827835
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  8.40029764175415
# average propensity for treated: 0.24933744966983795 and untreated: 0.17790570855140686
# average propensity for treated: 0.24933744966983795 and untreated: 0.17790570855140686
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  6.197054624557495
# average propensity for treated: 0.27297836542129517 and untreated: 0.17385922372341156
# average propensity for treated: 0.27297836542129517 and untreated: 0.17385922372341156
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  6.365773439407349
# average propensity for treated: 0.2524840533733368 and untreated: 0.18064488470554352
# average propensity for treated: 0.2524840533733368 and untreated: 0.18064488470554352
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  7.089536666870117
# average propensity for treated: 0.2626107931137085 and untreated: 0.1775059700012207
# average propensity for treated: 0.2626107931137085 and untreated: 0.1775059700012207
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  11.140022277832031
# average propensity for treated: 0.25746414065361023 and untreated: 0.17781946063041687
# average propensity for treated: 0.25746414065361023 and untreated: 0.17781946063041687
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  10.200212717056274
# average propensity for treated: 0.2753652036190033 and untreated: 0.17309458553791046
# average propensity for treated: 0.2753652036190033 and untreated: 0.17309458553791046
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  10.94747018814087
# average propensity for treated: 0.26195865869522095 and untreated: 0.17643249034881592
# average propensity for treated: 0.26195865869522095 and untreated: 0.17643249034881592
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  12.420479774475098
# average propensity for treated: 0.2713414132595062 and untreated: 0.17461645603179932
# average propensity for treated: 0.2713414132595062 and untreated: 0.17461645603179932
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  10.520371675491333
# average propensity for treated: 0.24988670647144318 and untreated: 0.17813533544540405
# average propensity for treated: 0.24988670647144318 and untreated: 0.17813533544540405
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  10.087655782699585
# average propensity for treated: 0.2630576193332672 and untreated: 0.1768300086259842
# average propensity for treated: 0.2630576193332672 and untreated: 0.1768300086259842
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  7.352024078369141
# average propensity for treated: 0.26249319314956665 and untreated: 0.17890137434005737
# average propensity for treated: 0.26249319314956665 and untreated: 0.17890137434005737
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  5.957165956497192
# average propensity for treated: 0.26787763833999634 and untreated: 0.17661824822425842
# average propensity for treated: 0.26787763833999634 and untreated: 0.17661824822425842
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  6.220826148986816
# average propensity for treated: 0.2605350911617279 and untreated: 0.1791607290506363
# average propensity for treated: 0.2605350911617279 and untreated: 0.1791607290506363
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  10.736912488937378
# average propensity for treated: 0.27714285254478455 and untreated: 0.1735132485628128
# average propensity for treated: 0.27714285254478455 and untreated: 0.1735132485628128
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  8.427134990692139
# average propensity for treated: 0.2510412335395813 and untreated: 0.1796722412109375
# average propensity for treated: 0.2510412335395813 and untreated: 0.1796722412109375
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  7.834648847579956
# average propensity for treated: 0.26073822379112244 and untreated: 0.1776675134897232
# average propensity for treated: 0.26073822379112244 and untreated: 0.1776675134897232
# Is targeted regularization: True
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  13.917994976043701
# average propensity for treated: 0.27911943197250366 and untreated: 0.17247529327869415
# average propensity for treated: 0.27911943197250366 and untreated: 0.17247529327869415
# Is targeted regularization: False
# 0.2
# I am here making dragonnet
# ***************************** elapsed_time is:  12.232840776443481
# average propensity for treated: 0.2829749584197998 and untreated: 0.17179922759532928
# average propensity for treated: 0.2829749584197998 and untreated: 0.17179922759532928
# run_dragonnet_done

# %% [markdown]
# # **Run Tarnet**

# %%
def main():
    #turn_knob(args.data_base_dir, args.knob, args.folder, args.output_base_dir, args.dataset)
    turn_knob(data_base_dir='/content/drive/My Drive/Colab Notebooks/dragonnet-master/dat/ihdp/csv',  # need to change 
    knob='tarnet', 
    output_base_dir='/content/drive/My Drive/Colab Notebooks/dragonnet-master/src/Result') # need to change 


if __name__ == '__main__':
    main()

print("run_tarnet_done")
# Out:
# the dragon is tarnet
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  10.75789499282837
# average propensity for treated: 0.22903676331043243 and untreated: 0.19930854439735413
# average propensity for treated: 0.22903676331043243 and untreated: 0.19930854439735413
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  14.935969591140747
# average propensity for treated: 0.22028951346874237 and untreated: 0.19980835914611816
# average propensity for treated: 0.22028951346874237 and untreated: 0.19980835914611816
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  14.626362562179565
# average propensity for treated: 0.23393040895462036 and untreated: 0.20653831958770752
# average propensity for treated: 0.23393040895462036 and untreated: 0.20653831958770752
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  14.553131580352783
# average propensity for treated: 0.2273164689540863 and untreated: 0.21850959956645966
# average propensity for treated: 0.2273164689540863 and untreated: 0.21850959956645966
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  15.64420199394226
# average propensity for treated: 0.21635228395462036 and untreated: 0.20772460103034973
# average propensity for treated: 0.21635228395462036 and untreated: 0.20772460103034973
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  13.502757549285889
# average propensity for treated: 0.21737243235111237 and untreated: 0.20149214565753937
# average propensity for treated: 0.21737243235111237 and untreated: 0.20149214565753937
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  16.230571031570435
# average propensity for treated: 0.21399086713790894 and untreated: 0.20374958217144012
# average propensity for treated: 0.21399086713790894 and untreated: 0.20374958217144012
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  12.242889404296875
# average propensity for treated: 0.2189197838306427 and untreated: 0.19895890355110168
# average propensity for treated: 0.2189197838306427 and untreated: 0.19895890355110168
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  16.016180992126465
# average propensity for treated: 0.231916144490242 and untreated: 0.2159477174282074
# average propensity for treated: 0.231916144490242 and untreated: 0.2159477174282074
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  13.203158378601074
# average propensity for treated: 0.21041733026504517 and untreated: 0.19312287867069244
# average propensity for treated: 0.21041733026504517 and untreated: 0.19312287867069244
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  10.553919553756714
# average propensity for treated: 0.23132933676242828 and untreated: 0.19665205478668213
# average propensity for treated: 0.23132933676242828 and untreated: 0.19665205478668213
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  9.434797048568726
# average propensity for treated: 0.22045570611953735 and untreated: 0.2021200805902481
# average propensity for treated: 0.22045570611953735 and untreated: 0.2021200805902481
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  15.556657552719116
# average propensity for treated: 0.21405717730522156 and untreated: 0.2044498175382614
# average propensity for treated: 0.21405717730522156 and untreated: 0.2044498175382614
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  12.977182149887085
# average propensity for treated: 0.24200153350830078 and untreated: 0.20409046113491058
# average propensity for treated: 0.24200153350830078 and untreated: 0.20409046113491058
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  14.058698177337646
# average propensity for treated: 0.2555067539215088 and untreated: 0.2036551982164383
# average propensity for treated: 0.2555067539215088 and untreated: 0.2036551982164383
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  11.559025764465332
# average propensity for treated: 0.23664405941963196 and untreated: 0.20224936306476593
# average propensity for treated: 0.23664405941963196 and untreated: 0.20224936306476593
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  9.883565664291382
# average propensity for treated: 0.2287224531173706 and untreated: 0.203265979886055
# average propensity for treated: 0.2287224531173706 and untreated: 0.203265979886055
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  12.915302515029907
# average propensity for treated: 0.230571910738945 and untreated: 0.21820610761642456
# average propensity for treated: 0.230571910738945 and untreated: 0.21820610761642456
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  10.783671379089355
# average propensity for treated: 0.2353580892086029 and untreated: 0.20045876502990723
# average propensity for treated: 0.2353580892086029 and untreated: 0.20045876502990723
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  13.13239598274231
# average propensity for treated: 0.24049872159957886 and untreated: 0.21080678701400757
# average propensity for treated: 0.24049872159957886 and untreated: 0.21080678701400757
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  13.13943099975586
# average propensity for treated: 0.22548545897006989 and untreated: 0.21101441979408264
# average propensity for treated: 0.22548545897006989 and untreated: 0.21101441979408264
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  12.944698333740234
# average propensity for treated: 0.20569981634616852 and untreated: 0.21394696831703186
# average propensity for treated: 0.20569981634616852 and untreated: 0.21394696831703186
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  9.150706052780151
# average propensity for treated: 0.20911727845668793 and untreated: 0.20478232204914093
# average propensity for treated: 0.20911727845668793 and untreated: 0.20478232204914093
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  12.866638898849487
# average propensity for treated: 0.23619070649147034 and untreated: 0.19954581558704376
# average propensity for treated: 0.23619070649147034 and untreated: 0.19954581558704376
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  10.152377128601074
# average propensity for treated: 0.24540938436985016 and untreated: 0.1956559270620346
# average propensity for treated: 0.24540938436985016 and untreated: 0.1956559270620346
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  11.129777193069458
# average propensity for treated: 0.2160009741783142 and untreated: 0.20010952651500702
# average propensity for treated: 0.2160009741783142 and untreated: 0.20010952651500702
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  16.449191331863403
# average propensity for treated: 0.2100987583398819 and untreated: 0.1997254639863968
# average propensity for treated: 0.2100987583398819 and untreated: 0.1997254639863968
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  13.546099662780762
# average propensity for treated: 0.2247190624475479 and untreated: 0.19761177897453308
# average propensity for treated: 0.2247190624475479 and untreated: 0.19761177897453308
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  8.970126390457153
# average propensity for treated: 0.23156216740608215 and untreated: 0.21601638197898865
# average propensity for treated: 0.23156216740608215 and untreated: 0.21601638197898865
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  12.581537008285522
# average propensity for treated: 0.19508834183216095 and untreated: 0.20108315348625183
# average propensity for treated: 0.19508834183216095 and untreated: 0.20108315348625183
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  13.066764116287231
# average propensity for treated: 0.21915630996227264 and untreated: 0.1937713623046875
# average propensity for treated: 0.21915630996227264 and untreated: 0.1937713623046875
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  14.950436353683472
# average propensity for treated: 0.20937493443489075 and untreated: 0.2047840654850006
# average propensity for treated: 0.20937493443489075 and untreated: 0.2047840654850006
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  15.411359548568726
# average propensity for treated: 0.22430795431137085 and untreated: 0.19495776295661926
# average propensity for treated: 0.22430795431137085 and untreated: 0.19495776295661926
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  15.057784080505371
# average propensity for treated: 0.2337842732667923 and untreated: 0.20609703660011292
# average propensity for treated: 0.2337842732667923 and untreated: 0.20609703660011292
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  14.584102153778076
# average propensity for treated: 0.20504502952098846 and untreated: 0.19998164474964142
# average propensity for treated: 0.20504502952098846 and untreated: 0.19998164474964142
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  11.787234544754028
# average propensity for treated: 0.24429941177368164 and untreated: 0.2106090784072876
# average propensity for treated: 0.24429941177368164 and untreated: 0.2106090784072876
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  12.942485809326172
# average propensity for treated: 0.2369905412197113 and untreated: 0.20857210457324982
# average propensity for treated: 0.2369905412197113 and untreated: 0.20857210457324982
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  12.426872968673706
# average propensity for treated: 0.2032674103975296 and untreated: 0.20601843297481537
# average propensity for treated: 0.2032674103975296 and untreated: 0.20601843297481537
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  11.346162796020508
# average propensity for treated: 0.20560060441493988 and untreated: 0.19821561872959137
# average propensity for treated: 0.20560060441493988 and untreated: 0.19821561872959137
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  13.508468866348267
# average propensity for treated: 0.224586620926857 and untreated: 0.20093709230422974
# average propensity for treated: 0.224586620926857 and untreated: 0.20093709230422974
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  14.584330558776855
# average propensity for treated: 0.23366354405879974 and untreated: 0.19814656674861908
# average propensity for treated: 0.23366354405879974 and untreated: 0.19814656674861908
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  13.18338131904602
# average propensity for treated: 0.1964898705482483 and untreated: 0.19997331500053406
# average propensity for treated: 0.1964898705482483 and untreated: 0.19997331500053406
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  14.334086418151855
# average propensity for treated: 0.22046448290348053 and untreated: 0.19635142385959625
# average propensity for treated: 0.22046448290348053 and untreated: 0.19635142385959625
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  14.089341402053833
# average propensity for treated: 0.21674814820289612 and untreated: 0.2023765593767166
# average propensity for treated: 0.21674814820289612 and untreated: 0.2023765593767166
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  11.458237409591675
# average propensity for treated: 0.2152988463640213 and untreated: 0.1904975324869156
# average propensity for treated: 0.2152988463640213 and untreated: 0.1904975324869156
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  13.777376890182495
# average propensity for treated: 0.21075765788555145 and untreated: 0.1969756931066513
# average propensity for treated: 0.21075765788555145 and untreated: 0.1969756931066513
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  12.294832468032837
# average propensity for treated: 0.23381918668746948 and untreated: 0.19776268303394318
# average propensity for treated: 0.23381918668746948 and untreated: 0.19776268303394318
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  13.912613868713379
# average propensity for treated: 0.20891669392585754 and untreated: 0.19505290687084198
# average propensity for treated: 0.20891669392585754 and untreated: 0.19505290687084198
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  14.562938690185547
# average propensity for treated: 0.2277098149061203 and untreated: 0.19972819089889526
# average propensity for treated: 0.2277098149061203 and untreated: 0.19972819089889526
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  13.270286560058594
# average propensity for treated: 0.21157842874526978 and untreated: 0.19703863561153412
# average propensity for treated: 0.21157842874526978 and untreated: 0.19703863561153412
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  14.512701988220215
# average propensity for treated: 0.21222923696041107 and untreated: 0.19778679311275482
# average propensity for treated: 0.21222923696041107 and untreated: 0.19778679311275482
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  12.265969038009644
# average propensity for treated: 0.21265342831611633 and untreated: 0.19375060498714447
# average propensity for treated: 0.21265342831611633 and untreated: 0.19375060498714447
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  11.91197919845581
# average propensity for treated: 0.21130651235580444 and untreated: 0.19619391858577728
# average propensity for treated: 0.21130651235580444 and untreated: 0.19619391858577728
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  12.683277606964111
# average propensity for treated: 0.22596974670886993 and untreated: 0.20340271294116974
# average propensity for treated: 0.22596974670886993 and untreated: 0.20340271294116974
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  11.807224750518799
# average propensity for treated: 0.2315586507320404 and untreated: 0.1982276290655136
# average propensity for treated: 0.2315586507320404 and untreated: 0.1982276290655136
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  11.529513120651245
# average propensity for treated: 0.2172112613916397 and untreated: 0.19755953550338745
# average propensity for treated: 0.2172112613916397 and untreated: 0.19755953550338745
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  11.835939168930054
# average propensity for treated: 0.22807379066944122 and untreated: 0.19152657687664032
# average propensity for treated: 0.22807379066944122 and untreated: 0.19152657687664032
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  12.44877815246582
# average propensity for treated: 0.20874816179275513 and untreated: 0.19607774913311005
# average propensity for treated: 0.20874816179275513 and untreated: 0.19607774913311005
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  14.717515230178833
# average propensity for treated: 0.26450368762016296 and untreated: 0.20489412546157837
# average propensity for treated: 0.26450368762016296 and untreated: 0.20489412546157837
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  13.670601606369019
# average propensity for treated: 0.21604564785957336 and untreated: 0.20321017503738403
# average propensity for treated: 0.21604564785957336 and untreated: 0.20321017503738403
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  14.562381029129028
# average propensity for treated: 0.21730893850326538 and untreated: 0.19417719542980194
# average propensity for treated: 0.21730893850326538 and untreated: 0.19417719542980194
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  13.123891353607178
# average propensity for treated: 0.215341255068779 and untreated: 0.19257625937461853
# average propensity for treated: 0.215341255068779 and untreated: 0.19257625937461853
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  13.891222715377808
# average propensity for treated: 0.2124645859003067 and untreated: 0.20421156287193298
# average propensity for treated: 0.2124645859003067 and untreated: 0.20421156287193298
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  13.902479887008667
# average propensity for treated: 0.24758581817150116 and untreated: 0.19828197360038757
# average propensity for treated: 0.24758581817150116 and untreated: 0.19828197360038757
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  13.772759914398193
# average propensity for treated: 0.23776568472385406 and untreated: 0.19987981021404266
# average propensity for treated: 0.23776568472385406 and untreated: 0.19987981021404266
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  14.9661283493042
# average propensity for treated: 0.2332525998353958 and untreated: 0.19533365964889526
# average propensity for treated: 0.2332525998353958 and untreated: 0.19533365964889526
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  14.219331741333008
# average propensity for treated: 0.2341141253709793 and untreated: 0.18944193422794342
# average propensity for treated: 0.2341141253709793 and untreated: 0.18944193422794342
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  12.641237258911133
# average propensity for treated: 0.21953576803207397 and untreated: 0.20748022198677063
# average propensity for treated: 0.21953576803207397 and untreated: 0.20748022198677063
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  12.501421689987183
# average propensity for treated: 0.2516712248325348 and untreated: 0.1997343748807907
# average propensity for treated: 0.2516712248325348 and untreated: 0.1997343748807907
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  13.235164642333984
# average propensity for treated: 0.2281574010848999 and untreated: 0.21095290780067444
# average propensity for treated: 0.2281574010848999 and untreated: 0.21095290780067444
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  14.363920450210571
# average propensity for treated: 0.21795737743377686 and untreated: 0.21218924224376678
# average propensity for treated: 0.21795737743377686 and untreated: 0.21218924224376678
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  12.327627897262573
# average propensity for treated: 0.2377808392047882 and untreated: 0.20283523201942444
# average propensity for treated: 0.2377808392047882 and untreated: 0.20283523201942444
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  9.084991931915283
# average propensity for treated: 0.24113145470619202 and untreated: 0.20951445400714874
# average propensity for treated: 0.24113145470619202 and untreated: 0.20951445400714874
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  12.971675634384155
# average propensity for treated: 0.23536309599876404 and untreated: 0.20067432522773743
# average propensity for treated: 0.23536309599876404 and untreated: 0.20067432522773743
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  11.392718076705933
# average propensity for treated: 0.21579305827617645 and untreated: 0.19715897738933563
# average propensity for treated: 0.21579305827617645 and untreated: 0.19715897738933563
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  12.19515347480774
# average propensity for treated: 0.2452881634235382 and untreated: 0.18936340510845184
# average propensity for treated: 0.2452881634235382 and untreated: 0.18936340510845184
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  15.677733898162842
# average propensity for treated: 0.19790169596672058 and untreated: 0.1997271478176117
# average propensity for treated: 0.19790169596672058 and untreated: 0.1997271478176117
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  13.027939081192017
# average propensity for treated: 0.2426002025604248 and untreated: 0.2022952437400818
# average propensity for treated: 0.2426002025604248 and untreated: 0.2022952437400818
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  15.865089654922485
# average propensity for treated: 0.2513202130794525 and untreated: 0.19972963631153107
# average propensity for treated: 0.2513202130794525 and untreated: 0.19972963631153107
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  12.634818077087402
# average propensity for treated: 0.2408176064491272 and untreated: 0.2006014734506607
# average propensity for treated: 0.2408176064491272 and untreated: 0.2006014734506607
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  13.91954231262207
# average propensity for treated: 0.20859882235527039 and untreated: 0.19670632481575012
# average propensity for treated: 0.20859882235527039 and untreated: 0.19670632481575012
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  12.625998258590698
# average propensity for treated: 0.21429097652435303 and untreated: 0.20752327144145966
# average propensity for treated: 0.21429097652435303 and untreated: 0.20752327144145966
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  12.957481384277344
# average propensity for treated: 0.2197001427412033 and untreated: 0.19558733701705933
# average propensity for treated: 0.2197001427412033 and untreated: 0.19558733701705933
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  13.680646896362305
# average propensity for treated: 0.20287533104419708 and untreated: 0.20224250853061676
# average propensity for treated: 0.20287533104419708 and untreated: 0.20224250853061676
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  11.533427238464355
# average propensity for treated: 0.21605750918388367 and untreated: 0.19609783589839935
# average propensity for treated: 0.21605750918388367 and untreated: 0.19609783589839935
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  12.788981676101685
# average propensity for treated: 0.2290947437286377 and untreated: 0.19334252178668976
# average propensity for treated: 0.2290947437286377 and untreated: 0.19334252178668976
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  11.019347906112671
# average propensity for treated: 0.2481663078069687 and untreated: 0.18968117237091064
# average propensity for treated: 0.2481663078069687 and untreated: 0.18968117237091064
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  15.379571199417114
# average propensity for treated: 0.22233161330223083 and untreated: 0.1947588473558426
# average propensity for treated: 0.22233161330223083 and untreated: 0.1947588473558426
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  12.945042848587036
# average propensity for treated: 0.2285805493593216 and untreated: 0.1941053867340088
# average propensity for treated: 0.2285805493593216 and untreated: 0.1941053867340088
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  14.145959615707397
# average propensity for treated: 0.22916874289512634 and untreated: 0.19598568975925446
# average propensity for treated: 0.22916874289512634 and untreated: 0.19598568975925446
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  10.513311624526978
# average propensity for treated: 0.20443399250507355 and untreated: 0.19907544553279877
# average propensity for treated: 0.20443399250507355 and untreated: 0.19907544553279877
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  13.844417572021484
# average propensity for treated: 0.1966281533241272 and untreated: 0.2020357996225357
# average propensity for treated: 0.1966281533241272 and untreated: 0.2020357996225357
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  11.031883239746094
# average propensity for treated: 0.22230388224124908 and untreated: 0.20391157269477844
# average propensity for treated: 0.22230388224124908 and untreated: 0.20391157269477844
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  14.57326889038086
# average propensity for treated: 0.22653628885746002 and untreated: 0.206369549036026
# average propensity for treated: 0.22653628885746002 and untreated: 0.206369549036026
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  9.037416934967041
# average propensity for treated: 0.21717143058776855 and untreated: 0.1983996331691742
# average propensity for treated: 0.21717143058776855 and untreated: 0.1983996331691742
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  14.413548946380615
# average propensity for treated: 0.20125795900821686 and untreated: 0.1952327936887741
# average propensity for treated: 0.20125795900821686 and untreated: 0.1952327936887741
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  10.553522109985352
# average propensity for treated: 0.1975622922182083 and untreated: 0.20644403994083405
# average propensity for treated: 0.1975622922182083 and untreated: 0.20644403994083405
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  10.001541137695312
# average propensity for treated: 0.22352871298789978 and untreated: 0.19939160346984863
# average propensity for treated: 0.22352871298789978 and untreated: 0.19939160346984863
# Is targeted regularization: True
# 0.2
# ***************************** elapsed_time is:  16.090889930725098
# average propensity for treated: 0.1921500265598297 and untreated: 0.20653818547725677
# average propensity for treated: 0.1921500265598297 and untreated: 0.20653818547725677
# Is targeted regularization: False
# 0.2
# ***************************** elapsed_time is:  15.329654932022095
# average propensity for treated: 0.22818681597709656 and untreated: 0.1931624412536621
# average propensity for treated: 0.22818681597709656 and untreated: 0.1931624412536621
# run_tarnet_done

# %% [markdown]
# # **Run Nednet**

# %%
def main():
    #turn_knob(args.data_base_dir, args.knob, args.folder, args.output_base_dir, args.dataset)
    turn_knob(data_base_dir='/content/drive/My Drive/Colab Notebooks/dragonnet-master/dat/ihdp/csv',  # need to change 
    knob='nednet', 
    output_base_dir='/content/drive/My Drive/Colab Notebooks/dragonnet-master/src/Result') # need to change 


if __name__ == '__main__':
    main()

print("run_nednet_done")
# Out:
# the dragon is nednet
# Is targeted regularization: True
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.29392847418785095 and untreated: 0.17672918736934662
# average propensity for treated: 0.29392847418785095 and untreated: 0.17672918736934662
# Is targeted regularization: False
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.29127031564712524 and untreated: 0.17794989049434662
# average propensity for treated: 0.29127031564712524 and untreated: 0.17794989049434662
# Is targeted regularization: True
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.2886454164981842 and untreated: 0.1781463623046875
# average propensity for treated: 0.2886454164981842 and untreated: 0.1781463623046875
# Is targeted regularization: False
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.29291823506355286 and untreated: 0.17736206948757172
# average propensity for treated: 0.29291823506355286 and untreated: 0.17736206948757172
# Is targeted regularization: True
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.27031537890434265 and untreated: 0.18230682611465454
# average propensity for treated: 0.27031537890434265 and untreated: 0.18230682611465454
# Is targeted regularization: False
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.2875877320766449 and untreated: 0.17853368818759918
# average propensity for treated: 0.2875877320766449 and untreated: 0.17853368818759918
# Is targeted regularization: True
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.2877744734287262 and untreated: 0.17848660051822662
# average propensity for treated: 0.2877744734287262 and untreated: 0.17848660051822662
# Is targeted regularization: False
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.29318150877952576 and untreated: 0.17728950083255768
# average propensity for treated: 0.29318150877952576 and untreated: 0.17728950083255768
# Is targeted regularization: True
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.2916523218154907 and untreated: 0.17750388383865356
# average propensity for treated: 0.2916523218154907 and untreated: 0.17750388383865356
# Is targeted regularization: False
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.28747597336769104 and untreated: 0.17981311678886414
# average propensity for treated: 0.28747597336769104 and untreated: 0.17981311678886414
# Is targeted regularization: True
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.27534031867980957 and untreated: 0.18043920397758484
# average propensity for treated: 0.27534031867980957 and untreated: 0.18043920397758484
# Is targeted regularization: False
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.2922872006893158 and untreated: 0.17770645022392273
# average propensity for treated: 0.2922872006893158 and untreated: 0.17770645022392273
# Is targeted regularization: True
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.2900865972042084 and untreated: 0.17911958694458008
# average propensity for treated: 0.2900865972042084 and untreated: 0.17911958694458008
# Is targeted regularization: False
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.2721834182739258 and untreated: 0.18285785615444183
# average propensity for treated: 0.2721834182739258 and untreated: 0.18285785615444183
# Is targeted regularization: True
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.29291823506355286 and untreated: 0.17736206948757172
# average propensity for treated: 0.29291823506355286 and untreated: 0.17736206948757172
# Is targeted regularization: False
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.29388564825057983 and untreated: 0.1771826595067978
# average propensity for treated: 0.29388564825057983 and untreated: 0.1771826595067978
# Is targeted regularization: True
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.27055299282073975 and untreated: 0.18228617310523987
# average propensity for treated: 0.27055299282073975 and untreated: 0.18228617310523987
# Is targeted regularization: False
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.28687483072280884 and untreated: 0.1789758950471878
# average propensity for treated: 0.28687483072280884 and untreated: 0.1789758950471878
# Is targeted regularization: True
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.2930102050304413 and untreated: 0.17762283980846405
# average propensity for treated: 0.2930102050304413 and untreated: 0.17762283980846405
# Is targeted regularization: False
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.28283798694610596 and untreated: 0.18064938485622406
# average propensity for treated: 0.28283798694610596 and untreated: 0.18064938485622406
# Is targeted regularization: True
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.29287007451057434 and untreated: 0.17801423370838165
# average propensity for treated: 0.29287007451057434 and untreated: 0.17801423370838165
# Is targeted regularization: False
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.2919783592224121 and untreated: 0.17757105827331543
# average propensity for treated: 0.2919783592224121 and untreated: 0.17757105827331543
# ...
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.28577592968940735 and untreated: 0.17890000343322754
# average propensity for treated: 0.28577592968940735 and untreated: 0.17890000343322754
# Is targeted regularization: False
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.28598055243492126 and untreated: 0.17887216806411743
# average propensity for treated: 0.28598055243492126 and untreated: 0.17887216806411743
# Is targeted regularization: True
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.29312968254089355 and untreated: 0.17724493145942688
# average propensity for treated: 0.29312968254089355 and untreated: 0.17724493145942688
# Is targeted regularization: False
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.2922618091106415 and untreated: 0.17736487090587616
# average propensity for treated: 0.2922618091106415 and untreated: 0.17736487090587616
# Is targeted regularization: True
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.2936353087425232 and untreated: 0.17734676599502563
# average propensity for treated: 0.2936353087425232 and untreated: 0.17734676599502563
# Is targeted regularization: False
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.28565165400505066 and untreated: 0.17881564795970917
# average propensity for treated: 0.28565165400505066 and untreated: 0.17881564795970917
# Is targeted regularization: True
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.2931038737297058 and untreated: 0.17732985317707062
# average propensity for treated: 0.2931038737297058 and untreated: 0.17732985317707062
# Is targeted regularization: False
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 25)           0
# __________________________________________________________________________________________________
# ned_hidden1 (Dense)             (None, 200)          5200        input[0][0]
# __________________________________________________________________________________________________
# ned_hidden2 (Dense)             (None, 200)          40200       ned_hidden1[0][0]
# __________________________________________________________________________________________________
# ned_hidden3 (Dense)             (None, 200)          40200       ned_hidden2[0][0]
# __________________________________________________________________________________________________
# ned_y_prediction (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# ned_t_activation (Dense)        (None, 1)            201         ned_hidden3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 2)            0           ned_y_prediction[0][0]
#                                                                  ned_t_activation[0][0]
# ==================================================================================================
# Total params: 86,002
# Trainable params: 86,002
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# average propensity for treated: 0.2886454164981842 and untreated: 0.1781463623046875
# average propensity for treated: 0.2886454164981842 and untreated: 0.1781463623046875
# run_nednet_done

# %% [markdown]
# # **idhp_ate.py**
# \delta_in

# %%
import copy

from numpy import load

from semi_parametric_estimation.ate import *


def load_truth(replication, knob):
    """
    loading ground truth data
    """

    file_path = '/content/drive/My Drive/Colab Notebooks/dragonnet-master/src/Result/{}/{}/simulation_outputs.npz'.format(knob, replication)
    data = load(file_path)
    mu_0 = data['mu_0']
    mu_1 = data['mu_1']

    return mu_1, mu_0


def load_data(knob='default', replication=1, model='baseline', train_test='test'):
    """
    loading train test experiment results
    """

    file_path = '/content/drive/My Drive/Colab Notebooks/dragonnet-master/src/Result/{}/'.format(knob)
    data = load(file_path + '{}/{}/0_replication_{}.npz'.format(replication, model, train_test))

    return data['q_t0'].reshape(-1, 1), data['q_t1'].reshape(-1, 1), data['g'].reshape(-1, 1), \
           data['t'].reshape(-1, 1), data['y'].reshape(-1, 1), data['index'].reshape(-1, 1), data['eps'].reshape(-1, 1)


def get_estimate(q_t0, q_t1, g, t, y_dragon, index, eps, truncate_level=0.01):
    """
    getting the back door adjustment & TMLE estimation
    """

    psi_n = psi_naive(q_t0, q_t1, g, t, y_dragon, truncate_level=truncate_level)
    psi_tmle, psi_tmle_std, eps_hat, initial_loss, final_loss, g_loss = psi_tmle_cont_outcome(q_t0, q_t1, g, t,
                                                                                              y_dragon,
                                                                                              truncate_level=truncate_level)
    return psi_n, psi_tmle, initial_loss, final_loss, g_loss


def make_table(train_test='train', n_replication=50):
    dict = {'tarnet': {'baseline': {'back_door': 0, }, 'targeted_regularization': 0},
            'dragonnet': {'baseline': 0, 'targeted_regularization': 0},
            'nednet': {'baseline': 0, 'targeted_regularization': 0}}
    tmle_dict = copy.deepcopy(dict)

    for knob in ['dragonnet','tarnet','nednet']:
        for model in ['baseline', 'targeted_regularization']:
            simple_errors, tmle_errors = [], []
            for rep in range(n_replication):
                q_t0, q_t1, g, t, y_dragon, index, eps = load_data(knob, rep, model, train_test)
                a, b = load_truth(rep, knob)
                mu_1, mu_0 = a[index], b[index]

                truth = (mu_1 - mu_0).mean()

                psi_n, psi_tmle, initial_loss, final_loss, g_loss = get_estimate(q_t0, q_t1, g, t, y_dragon, index, eps,
                                                                                 truncate_level=0.01)

                err = abs(truth - psi_n).mean()
                tmle_err = abs(truth - psi_tmle).mean()
                simple_errors.append(err)
                tmle_errors.append(tmle_err)

            dict[knob][model] = np.mean(simple_errors)
            tmle_dict[knob][model] = np.mean(tmle_errors)

    return dict, tmle_dict

# %% [markdown]
# # **idhp_ate_main.py**

# %%
def main():
    dict, tmle_dict = make_table()
    print("The back door adjustment result is below")
    print(dict)

    print("the tmle estimator result is this ")
    print(tmle_dict)


if __name__ == "__main__":
    main()
# Out:
# The back door adjustment result is below
# {'tarnet': {'baseline': 0.12504421744050617, 'targeted_regularization': 0.1191920418706454}, 'dragonnet': {'baseline': 0.12754051156209403, 'targeted_regularization': 0.14132166487134246}, 'nednet': {'baseline': 0.18165883789319032, 'targeted_regularization': 0.18931748731470793}}
# the tmle estimator result is this
# {'tarnet': {'baseline': 0.12316339778468582, 'targeted_regularization': 0.11989218527556239}, 'dragonnet': {'baseline': 0.1224153766497898, 'targeted_regularization': 0.1246210706505555}, 'nednet': {'baseline': 0.13364663677613112, 'targeted_regularization': 0.14120976249201458}}
